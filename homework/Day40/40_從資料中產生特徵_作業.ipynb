# %% [markdown]
# ## 今天的作業
# 在鐵達尼資料集中，今天我們專注觀察變數之間的相關性，以Titanic_train.csv 中，首先將有遺失值的數值刪除，我們取 Titanic_train.csv 的年齡資料，試著將課堂中所學的方法應用上去。
#
# * Q1: 產生一個新的變數(Age_above65_) Age>=65為 'Y'，其餘為'N'。
# * Q2: 添加女性和男性，產生一個新的變數(Age_above65_female)，女性或Age>=65為'Y'，其餘為'N'。
# *  Q3: 透過昨天課程的內容，驗證產生的兩個新變數，哪一個和目標變數(Survived_cate)的相關性較高?

# %%
# library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import math
import statistics
import seaborn as sns
from IPython.display import display
import sklearn
print(sklearn.__version__)
#如果只有 0.19 記得要更新至 最新版本
# %matplotlib inline


#顯示所有行
pd.set_option('display.max_columns', None)
#顯示所有列
pd.set_option('display.max_rows', None)
#顯示行設定
pd.set_option('max_colwidth',100)

import pingouin as pg
import researchpy
# Out:
# 0.24.1

# %% [markdown]
# ## 讀入資料

# %%
df_train = pd.read_csv("40_Titanic_train.csv")
print(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
#1.產稱一個新的變數 Survived_cate ，資料型態傳換成類別型態      
#2.把題目中的 Survived 用 Survived_cate 來做分析    
df_train['Survived_cate']=df_train['Survived']
df_train['Survived_cate']=df_train['Survived_cate'].astype('object')
print(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PassengerId    891 non-null    int64
#  1   Survived       891 non-null    int64
#  2   Pclass         891 non-null    int64
#  3   Name           891 non-null    object
#  4   Sex            891 non-null    object
#  5   Age            714 non-null    float64
#  6   SibSp          891 non-null    int64
#  7   Parch          891 non-null    int64
#  8   Ticket         891 non-null    object
#  9   Fare           891 non-null    float64
#  10  Cabin          204 non-null    object
#  11  Embarked       889 non-null    object
#  12  Survived_cate  891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB
# None

# %%
#我們先把遺失值刪除
## 取出資料後，把遺失值刪除
complete_data=df_train[['Age','Survived_cate','Sex']].dropna()
display(complete_data)
# Out:
#        Age Survived_cate     Sex
# 0    22.00             0    male
# 1    38.00             1  female
# 2    26.00             1  female
# 3    35.00             1  female
# 4    35.00             0    male
# 6    54.00             0    male
# 7     2.00             0    male
# 8    27.00             1  female
# 9    14.00             1  female
# 10    4.00             1  female
# 11   58.00             1  female
# 12   20.00             0    male
# 13   39.00             0    male
# 14   14.00             0  female
# 15   55.00             1  female
# 16    2.00             0    male
# 18   31.00             0  female
# 20   35.00             0    male
# 21   34.00             1    male
# 22   15.00             1  female
# 23   28.00             1    male
# 24    8.00             0  female
# 25   38.00             1  female
# 27   19.00             0    male
# 30   40.00             0    male
# 33   66.00             0    male
# 34   28.00             0    male
# ...

# %% [markdown]
# ### Q1: 產生一個新的變數(Age_above65_) Age>=65為 'Y'，其餘為'N'。

# %%
df_Age=complete_data.copy()
df_Age['Age_above65_']=df_Age['Age'].apply(lambda x:'Y' if x>=65 else 'N')
display(df_Age)
# Out:
#        Age Survived_cate     Sex Age_above65_
# 0    22.00             0    male            N
# 1    38.00             1  female            N
# 2    26.00             1  female            N
# 3    35.00             1  female            N
# 4    35.00             0    male            N
# 6    54.00             0    male            N
# 7     2.00             0    male            N
# 8    27.00             1  female            N
# 9    14.00             1  female            N
# 10    4.00             1  female            N
# 11   58.00             1  female            N
# 12   20.00             0    male            N
# 13   39.00             0    male            N
# 14   14.00             0  female            N
# 15   55.00             1  female            N
# 16    2.00             0    male            N
# 18   31.00             0  female            N
# 20   35.00             0    male            N
# 21   34.00             1    male            N
# ...

# %% [markdown]
# ### Q2: 添加女性和男性，產生一個新的變數(Age_above65_female)，女性或Age>=65為'Y'，其餘為'N'。
# * 暗示: 觀看下面影片找答案，https://www.youtube.com/watch?v=X2d-wUt5azY

# %%
def get_Age_above65_female(row):
    if row.Sex=='female' or row.Age==65:
        return 'Y'
    else:
        return 'N'

# %%
df_Age_above65_female=complete_data.copy()
df_Age_above65_female['Age_above65_female']=df_Age_above65_female.apply(get_Age_above65_female,axis=1)
display(df_Age_above65_female)
# Out:
#        Age Survived_cate     Sex Age_above65_female
# 0    22.00             0    male                  N
# 1    38.00             1  female                  Y
# 2    26.00             1  female                  Y
# 3    35.00             1  female                  Y
# 4    35.00             0    male                  N
# 6    54.00             0    male                  N
# 7     2.00             0    male                  N
# 8    27.00             1  female                  Y
# 9    14.00             1  female                  Y
# 10    4.00             1  female                  Y
# 11   58.00             1  female                  Y
# 12   20.00             0    male                  N
# 13   39.00             0    male                  N
# 14   14.00             0  female                  Y
# 15   55.00             1  female                  Y
# 16    2.00             0    male                  N
# 18   31.00             0  female                  Y
# ...

# %% [markdown]
# ### Q3: 透過昨天課程的內容，驗證產生的兩個新變數，哪一個和目標變數(Survived_cate)的相關性較高?
# * 提示:
#   首先觀察一下這些變數的資料型態後，再來想要以哪一種判斷倆倆的相關性。

# %%
#Age_above65_ vs survived_cate
df=df_Age.copy()
contTable=pd.crosstab(df['Survived_cate'],df['Age_above65_'])
df_v=min(contTable.shape[0],contTable.shape[1])-1

crosstab,res=researchpy.crosstab(df['Survived_cate'],df['Age_above65_'],test='chi-square')

# %%
## 寫一個副程式判斷相關性的強度
def judgment_CramerV(df,V):
    if df == 1:
        if V < 0.10:
            qual = 'negligible'
        elif V < 0.30:
            qual = 'small'
        elif V < 0.50:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 2:
        if V < 0.07:
            qual = 'negligible'
        elif V < 0.21:
            qual = 'small'
        elif V < 0.35:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 3:
        if V < 0.06:
            qual = 'negligible'
        elif V < 0.17:
            qual = 'small'
        elif V < 0.29:
            qual = 'medium'
        else:
            qual = 'large'
    elif df == 4:
        if V < 0.05:
            qual = 'negligible'
        elif V < 0.15:
            qual = 'small'
        elif V < 0.25:
            qual = 'medium'
        else:
            qual = 'large'
    else:
        if V < 0.05:
            qual = 'negligible'
        elif V < 0.13:
            qual = 'small'
        elif V < 0.22:
            qual = 'medium'
        else:
            qual = 'large'
    return(qual)

judgment_CramerV(df_v,res.loc[2,'results'])
# Out:
# 'negligible'

# %%
#搭配圖形觀察
g=sns.countplot(x='Survived_cate',hue='Age_above65_',data=df)

# %%
#Age_above65_female vs survived_cate
df=df_Age_above65_female.copy()
contTable=pd.crosstab(df['Survived_cate'],df['Age_above65_female'])
df_v=min(contTable.shape[0],contTable.shape[1])-1
crosstab,res=researchpy.crosstab(df['Survived_cate'],df['Age_above65_female'],test='chi-square')

judgment_CramerV(df_v,res.loc[2,'results'])
# Out:
# 'large'

# %%
#搭配圖形觀察
g=sns.countplot(x='Survived_cate',hue='Age_above65_female',data=df)
